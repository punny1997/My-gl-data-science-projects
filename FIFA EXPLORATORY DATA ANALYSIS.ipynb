# %% [markdown]
# #DATA PREPROCESSING

# %%
#1A)
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('fifa.csv')
df1
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# ...

# %%
df22=pd.read_csv('fifainfo.csv')
df22
# Out:
#                           ID          unique id for every player
# 0                       Name                                name
# 1                        Age                                 age
# 2                      Photo           url to the player's photo
# 3                Nationality                         nationality
# 4                       Flag       url to players's country flag
# 5                    Overall                      overall rating
# 6                  Potential                    potential rating
# 7                       Club                        current club
# 8                  Club Logo                    url to club logo
# 9                      Value                current market value
# 10                      Wage                        current wage
# 11            Preferred Foot                          left/right
# 12  International Reputation                rating on scale of 5
# ...

# %%
#3A)

# %%
df1['Release Clause 2'] = df1['Release Clause'].str.rstrip('M').str.lstrip('€').str.rstrip('K')
df1
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# ...

# %%
df1
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 61 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  object
#  11  Wage                      18207 non-null  object
#  12  Preferred Foot            18159 non-null  object
# ...

# %%
df1.drop(columns='Release Clause',inplace=True)

# %%
df1['Value']=df1['Value'].str.lstrip('€').str.rstrip('K').str.rstrip('M')

df1['Value']
# Out:
# 0        110.5
# 1           77
# 2        118.5
# 3           72
# 4          102
#          ...
# 18202       60
# 18203       60
# 18204       60
# 18205       60
# 18206       60
# Name: Value, Length: 18207, dtype: object

# %%
df1['Wage']=df1['Wage'].str.lstrip('€').str.rstrip('K')
df1['Wage']
# Out:
# 0        565
# 1        405
# 2        290
# 3        260
# 4        355
#         ...
# 18202      1
# 18203      1
# 18204      1
# 18205      1
# 18206      1
# Name: Wage, Length: 18207, dtype: object

# %%
df1['Joined']=pd.DatetimeIndex(df1['Joined'])
df1['Joined']
# Out:
# 0       2004-07-01
# 1       2018-07-10
# 2       2017-08-03
# 3       2011-07-01
# 4       2015-08-30
#            ...
# 18202   2017-05-03
# 18203   2018-03-19
# 18204   2017-07-01
# 18205   2018-04-24
# 18206   2018-10-30
# Name: Joined, Length: 18207, dtype: datetime64[ns]

# %%
df1['Contract Valid Until']=pd.DatetimeIndex(df1['Contract Valid Until'])
df1['Contract Valid Until']
# Out:
# 0       2021-01-01
# 1       2022-01-01
# 2       2022-01-01
# 3       2020-01-01
# 4       2023-01-01
#            ...
# 18202   2019-01-01
# 18203   2020-01-01
# 18204   2021-01-01
# 18205   2019-01-01
# 18206   2019-01-01
# Name: Contract Valid Until, Length: 18207, dtype: datetime64[ns]

# %%
df1['Height']
# Out:
# 0         5'7
# 1         6'2
# 2         5'9
# 3         6'4
# 4        5'11
#          ...
# 18202     5'9
# 18203     6'3
# 18204     5'8
# 18205    5'10
# 18206    5'10
# Name: Height, Length: 18207, dtype: object

# %%
df1['Height']=df1['Height'].replace("'", '', regex=True)
df1['Height']
# Out:
# 0         57
# 1         62
# 2         59
# 3         64
# 4        511
#         ...
# 18202     59
# 18203     63
# 18204     58
# 18205    510
# 18206    510
# Name: Height, Length: 18207, dtype: object

# %%
df1['Height']=df1['Height'].apply(lambda x:x/10)
df1['Height']
# Out:
# 0         5.7
# 1         6.2
# 2         5.9
# 3         6.4
# 4        51.1
#          ...
# 18202     5.9
# 18203     6.3
# 18204     5.8
# 18205    51.0
# 18206    51.0
# Name: Height, Length: 18207, dtype: float64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 60 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  float64
#  11  Wage                      18207 non-null  float64
#  12  Preferred Foot            18159 non-null  object
# ...

# %%
df1['Weight']=df1['Weight'].str.rstrip('lbs')

df1['Weight']
# Out:
# 0        159
# 1        183
# 2        150
# 3        168
# 4        154
#         ...
# 18202    134
# 18203    170
# 18204    148
# 18205    154
# 18206    176
# Name: Weight, Length: 18207, dtype: object

# %%
df1.isnull().sum()
# Out:
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# Weight                         48
# Crossing                       48
# Finishing                      48
# ...

# %%
print(df1['GKKicking'].skew())
print(df1['GKPositioning'].skew())
print(df1['GKReflexes'].skew())
print(df1['Release Clause 2'].skew())
print(df1['GKHandling'].skew())
print(df1['GKDiving'].skew())
print(df1['SlidingTackle'].skew())
print(df1['StandingTackle'].skew())
print(df1['Marking'].skew())
print(df1['Composure'].skew())
print(df1['Penalties'].skew())
print(df1['Vision'].skew())
print(df1['Positioning'].skew())
print(df1['Interceptions'].skew())
print(df1['Aggression'].skew())
print(df1['LongShots'].skew())
print(df1['Strength'].skew())
print(df1['Stamina'].skew())
print(df1['Jumping'].skew())
print(df1['ShotPower'].skew())
# Out:
# 2.4305755745229756
# 2.4637997920926717
# 2.4526381986316883
# 1.0695513335571176
# 2.4334936941638587
# 2.4410150962963906
# -0.26656336897029687
# -0.33660977914194523
# -0.36268006525542623
# -0.38103013176281764
# -0.35496830178573213
# -0.3507462736216748
# -0.7202194342184074
# -0.26838911211703614
# -0.4321682972668243
# -0.43227063575131036
# -0.46836460699283744
# -0.9153997188127042
# -0.45431885066506106
# -0.6804668399765457

# %%
print(df1['GKKicking'].median())
print(df1['GKPositioning'].median())
print(df1['GKReflexes'].median())
print(df1['Release Clause 2'].median())
# Out:
# 11.0
# 11.0
# 11.0
# 19.8

# %%
sns.distplot(df1['GKKicking'])
sns.distplot(df1['GKPositioning'])
sns.distplot(df1['Release Clause 2'])
sns.distplot(df1['SlidingTackle'])
# Out:
# c:\users\puneeth\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SlidingTackle', ylabel='Density'>

# %%
df1['GKKicking']=df1['GKKicking'].fillna(df1.GKKicking.median())
df1['GKKicking']
# Out:
# 0        15.0
# 1        15.0
# 2        15.0
# 3        87.0
# 4         5.0
#          ...
# 18202     7.0
# 18203     9.0
# 18204    10.0
# 18205    14.0
# 18206     9.0
# Name: GKKicking, Length: 18207, dtype: float64

# %%
df1['GKPositioning']=df1['GKPositioning'].fillna(df1.GKPositioning.median())
df1['GKPositioning']
# Out:
# 0        14.0
# 1        14.0
# 2        15.0
# 3        88.0
# 4        10.0
#          ...
# 18202     8.0
# 18203     5.0
# 18204     6.0
# 18205     8.0
# 18206    12.0
# Name: GKPositioning, Length: 18207, dtype: float64

# %%
df1['GKReflexes']=df1['GKReflexes'].fillna(df1.GKReflexes.median())
df1['GKReflexes']
# Out:
# 0         8.0
# 1        11.0
# 2        11.0
# 3        94.0
# 4        13.0
#          ...
# 18202     9.0
# 18203    12.0
# 18204    13.0
# 18205     9.0
# 18206     9.0
# Name: GKReflexes, Length: 18207, dtype: float64

# %%
df1['Release Clause 2']=df1['Release Clause 2'].fillna(df1['Release Clause 2'].median())
df1['Release Clause 2']
# Out:
# 0        226.5
# 1        127.1
# 2        228.1
# 3        138.6
# 4        196.4
#          ...
# 18202      143
# 18203      113
# 18204      165
# 18205      143
# 18206      165
# Name: Release Clause 2, Length: 18207, dtype: object

# %%
df1.isnull().sum()
# Out:
# ID                     0
# Name                   0
# Age                    0
# Photo                  0
# Nationality            0
#                     ...
# GKKicking              0
# GKPositioning          0
# GKReflexes             0
# Release Clause      1564
# Release Clause 2       0
# Length: 61, dtype: int64

# %%
sns.histplot(df1['Overall'])
# Out:
# <AxesSubplot:xlabel='Overall', ylabel='Count'>

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 60 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  object
#  11  Wage                      18207 non-null  object
#  12  Preferred Foot            18159 non-null  object
# ...

# %%
df1 = df1.astype({"Wage":'float', "Value":'float',"Weight":'float',"Height":'float'})
  

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 60 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  float64
#  11  Wage                      18207 non-null  float64
#  12  Preferred Foot            18159 non-null  object
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 60 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  object
#  11  Wage                      18207 non-null  object
#  12  Preferred Foot            18159 non-null  object
# ...

# %% [markdown]
# Overall, Value, Wage, International Reputation, Weight, Release Clause

# %%
sns.pairplot(df1[['Overall', 'Value','Wage', 'International Reputation','Weight','Height','Release Clause 2']])

# %%
df2=df1[df1['Overall']>80] 
df2
# Out:
#          ID               Name  Age  \
# 0    158023           L. Messi   31
# 1     20801  Cristiano Ronaldo   33
# 2    190871          Neymar Jr   26
# 3    193080             De Gea   27
# 4    192985       K. De Bruyne   27
# ..      ...                ...  ...
# 407  144622            Raffael   33
# 408  139068               Nani   31
# 409  138412          J. Milner   32
# 410  112316         J. Mathieu   34
# 411   45186            Joaquín   36
#
#                                               Photo Nationality  \
# 0    https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1     https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2    https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3    https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4    https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ..                                              ...         ...
# 407  https://cdn.sofifa.org/players/4/19/144622.png      Brazil
# ...

# %%
df2[['Name','GKDiving','GKHandling','GKKicking','GKPositioning','GKReflexes','Wage','Overall']].sort_values(by=['GKDiving','GKHandling','GKKicking','GKPositioning','GKReflexes','Wage','Overall'],ascending=False).head(3)
# Out:
#         Name  GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  \
# 22  M. Neuer      90.0        86.0       91.0           87.0        87.0
# 3     De Gea      90.0        85.0       87.0           88.0        94.0
# 46  K. Navas      90.0        81.0       75.0           82.0        90.0
#
#      Wage  Overall
# 22  130.0       89
# 3   260.0       91
# 46  195.0       87

# %%
df2[['Name','GKDiving','GKHandling','GKKicking','GKPositioning','GKReflexes','Wage','Overall']].sort_values(by=['GKDiving','GKHandling','GKKicking','GKPositioning','GKReflexes','Wage','Overall'],ascending=False).head(3).plot(kind='bar',x='Name',y='Overall')
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
pd.unique(df2['Position'])
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF'], dtype=object)

# %%
df3=df1[(df1['Position']=='ST')|(df1['Position']=='CF')].head()
df3
# Out:
#         ID               Name  Age  \
# 1    20801  Cristiano Ronaldo   33
# 10  188545     R. Lewandowski   29
# 16  202126            H. Kane   24
# 23  153079          S. Agüero   30
# 36  173731            G. Bale   28
#
#                                              Photo Nationality  \
# 1    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 10  https://cdn.sofifa.org/players/4/19/188545.png      Poland
# 16  https://cdn.sofifa.org/players/4/19/202126.png     England
# 23  https://cdn.sofifa.org/players/4/19/153079.png   Argentina
# 36  https://cdn.sofifa.org/players/4/19/173731.png       Wales
#
#                                    Flag  Overall  Potential  \
# 1   https://cdn.sofifa.org/flags/38.png       94         94
# 10  https://cdn.sofifa.org/flags/37.png       90         90
# 16  https://cdn.sofifa.org/flags/14.png       89         91
# 23  https://cdn.sofifa.org/flags/52.png       89         89
# 36  https://cdn.sofifa.org/flags/50.png       88         88
#
# ...

# %%
df3[['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name'],ascending=False).head(5)
# Out:
#     Overall  Finishing  HeadingAccuracy  Dribbling  SprintSpeed  Acceleration  \
# 1        94       94.0             89.0       88.0         91.0          89.0
# 10       90       91.0             85.0       85.0         78.0          77.0
# 16       89       94.0             85.0       80.0         72.0          68.0
# 23       89       93.0             77.0       89.0         80.0          88.0
# 36       88       86.0             84.0       87.0         95.0          94.0
#
#     Agility  ShotPower  Strength  LongShots  Stamina  BallControl Position  \
# 1      87.0       95.0      79.0       93.0     88.0         94.0       ST
# 10     78.0       88.0      84.0       84.0     78.0         89.0       ST
# 16     71.0       88.0      84.0       85.0     89.0         84.0       ST
# 23     86.0       88.0      73.0       83.0     76.0         89.0       ST
# 36     82.0       92.0      80.0       91.0     75.0         85.0       ST
#
# ...

# %%
df3[['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name'],ascending=False).head(5).plot(kind='bar',x='Name',y='Overall')
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
df3['Wage_in_thousands_€']=df3['Wage'].mean()
df3
# Out:
#         ID               Name  Age  \
# 1    20801  Cristiano Ronaldo   33
# 10  188545     R. Lewandowski   29
# 16  202126            H. Kane   24
# 23  153079          S. Agüero   30
# 36  173731            G. Bale   28
#
#                                              Photo Nationality  \
# 1    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 10  https://cdn.sofifa.org/players/4/19/188545.png      Poland
# 16  https://cdn.sofifa.org/players/4/19/202126.png     England
# 23  https://cdn.sofifa.org/players/4/19/153079.png   Argentina
# 36  https://cdn.sofifa.org/players/4/19/173731.png       Wales
#
#                                    Flag  Overall  Potential  \
# 1   https://cdn.sofifa.org/flags/38.png       94         94
# 10  https://cdn.sofifa.org/flags/37.png       90         90
# 16  https://cdn.sofifa.org/flags/14.png       89         91
# 23  https://cdn.sofifa.org/flags/52.png       89         89
# 36  https://cdn.sofifa.org/flags/50.png       88         88
#
# ...

# %%
df33=df1[(df1['Position']=='ST') & (df1['Position']=='CF')].head(20)
df33
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value, Wage, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause 2]
# Index: []
#
# [0 rows x 60 columns]

# %%
df4=df1[(df1['Position']=='RF') |(df1['Position']=='RS') |(df1['Position']=='RW')  ].head()
df4
# Out:
#         ID            Name  Age  \
# 0   158023        L. Messi   31
# 7   176580       L. Suárez   31
# 50  175943      D. Mertens   31
# 56  218667  Bernardo Silva   23
# 60  202652     R. Sterling   23
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 7   https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# 50  https://cdn.sofifa.org/players/4/19/175943.png     Belgium
# 56  https://cdn.sofifa.org/players/4/19/218667.png    Portugal
# 60  https://cdn.sofifa.org/players/4/19/202652.png     England
#
#                                    Flag  Overall  Potential             Club  \
# 0   https://cdn.sofifa.org/flags/52.png       94         94     FC Barcelona
# 7   https://cdn.sofifa.org/flags/60.png       91         91     FC Barcelona
# 50   https://cdn.sofifa.org/flags/7.png       87         87           Napoli
# ...

# %%
df4[['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head()
# Out:
#     Overall  Finishing  HeadingAccuracy  Dribbling  SprintSpeed  Acceleration  \
# 0        94       95.0             70.0       97.0         86.0          91.0
# 7        91       93.0             77.0       87.0         75.0          86.0
# 50       87       86.0             35.0       91.0         85.0          93.0
# 60       86       77.0             38.0       88.0         92.0          95.0
# 56       86       75.0             51.0       92.0         74.0          84.0
#
#     Agility  ShotPower  Strength  LongShots  Stamina  BallControl Position  \
# 0      91.0       85.0      59.0       94.0     72.0         96.0       RF
# 7      82.0       86.0      83.0       85.0     90.0         90.0       RS
# 50     94.0       80.0      42.0       81.0     75.0         89.0       RF
# 60     93.0       73.0      52.0       73.0     78.0         87.0       RW
# 56     90.0       70.0      48.0       72.0     78.0         91.0       RW
#
# ...

# %%
df4[['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head().plot(kind='bar',x='Name',y='Overall')
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
df4['Wage_in_thousands_€']=df4['Wage'].mean()
df4
# Out:
#         ID            Name  Age  \
# 0   158023        L. Messi   31
# 7   176580       L. Suárez   31
# 50  175943      D. Mertens   31
# 56  218667  Bernardo Silva   23
# 60  202652     R. Sterling   23
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 7   https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# 50  https://cdn.sofifa.org/players/4/19/175943.png     Belgium
# 56  https://cdn.sofifa.org/players/4/19/218667.png    Portugal
# 60  https://cdn.sofifa.org/players/4/19/202652.png     England
#
#                                    Flag  Overall  Potential             Club  \
# 0   https://cdn.sofifa.org/flags/52.png       94         94     FC Barcelona
# 7   https://cdn.sofifa.org/flags/60.png       91         91     FC Barcelona
# 50   https://cdn.sofifa.org/flags/7.png       87         87           Napoli
# ...

# %%
df44=df1[(df1['Position']=='RF') &(df1['Position']=='RS') &(df1['Position']=='RW')  ]
df44
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value, Wage, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause 2]
# Index: []
#
# [0 rows x 60 columns]

# %%
df5=df1[(df1['Position']=='LW') | (df1['Position']=='LF')|(df1['Position']=='LS')].head(20)
df5
# Out:
#          ID            Name  Age  \
# 2    190871       Neymar Jr   26
# 5    183277       E. Hazard   27
# 15   211110       P. Dybala   24
# 21   179813       E. Cavani   31
# 29   198219      L. Insigne   27
# 30   197781            Isco   26
# 32   189242        Coutinho   26
# 38   167664      G. Higuaín   30
# 55   222492         L. Sané   22
# 76       41         Iniesta   34
# 100  179844     Diego Costa   29
# 116  211300      A. Martial   22
# 151  143076        A. Gómez   30
# 174  208093   Gerard Moreno   26
# 206  186627    M. Balotelli   27
# 252  208596      A. Belotti   24
# 270  198717         W. Zaha   25
# 272  198164  Jonathan Viera   28
# 294  184200   M. Arnautović   29
# 319  231677     M. Rashford   20
#
#                                               Photo  Nationality  \
# 2    https://cdn.sofifa.org/players/4/19/190871.png       Brazil
# 5    https://cdn.sofifa.org/players/4/19/183277.png      Belgium
# ...

# %%
df5[['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head().plot(kind='bar',x='Name',y='Overall')
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
df5[['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head()
# Out:
#     Overall  Finishing  HeadingAccuracy  Dribbling  SprintSpeed  Acceleration  \
# 2        92       87.0             62.0       96.0         90.0          94.0
# 5        91       84.0             61.0       95.0         88.0          94.0
# 21       89       89.0             89.0       80.0         76.0          75.0
# 15       89       84.0             68.0       92.0         83.0          87.0
# 38       88       92.0             80.0       84.0         73.0          73.0
#
#     Agility  ShotPower  Strength  LongShots  Stamina  BallControl Position  \
# 2      96.0       80.0      49.0       82.0     81.0         95.0       LW
# 5      95.0       82.0      66.0       80.0     83.0         94.0       LF
# 21     77.0       87.0      78.0       79.0     92.0         82.0       LS
# 15     91.0       82.0      65.0       88.0     80.0         92.0       LF
# 38     75.0       86.0      85.0       80.0     70.0         85.0       LS
#
# ...

# %%
df5['Wage_in_thousands_€']=df5['Wage'].mean()
df5
# Out:
#          ID            Name  Age  \
# 2    190871       Neymar Jr   26
# 5    183277       E. Hazard   27
# 15   211110       P. Dybala   24
# 21   179813       E. Cavani   31
# 29   198219      L. Insigne   27
# 30   197781            Isco   26
# 32   189242        Coutinho   26
# 38   167664      G. Higuaín   30
# 55   222492         L. Sané   22
# 76       41         Iniesta   34
# 100  179844     Diego Costa   29
# 116  211300      A. Martial   22
# 151  143076        A. Gómez   30
# 174  208093   Gerard Moreno   26
# 206  186627    M. Balotelli   27
# 252  208596      A. Belotti   24
# 270  198717         W. Zaha   25
# 272  198164  Jonathan Viera   28
# 294  184200   M. Arnautović   29
# 319  231677     M. Rashford   20
#
#                                               Photo  Nationality  \
# 2    https://cdn.sofifa.org/players/4/19/190871.png       Brazil
# 5    https://cdn.sofifa.org/players/4/19/183277.png      Belgium
# ...

# %%
df55=df1[(df1['Position']=='LW') & (df1['Position']=='LF')&(df1['Position']=='LS')].head(20)
df55
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value, Wage, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause 2]
# Index: []
#
# [0 rows x 60 columns]

# %%
df6=df1[(df1['Position']=='RCM') | (df1['Position']=='LCM') | ((df1['Position']=='CM'))].head(20)
df6
# Out:
#          ID                 Name  Age  \
# 4    192985         K. De Bruyne   27
# 6    177003            L. Modrić   32
# 11   182521             T. Kroos   28
# 13   168542          David Silva   32
# 52   171877            M. Hamšík   30
# 53   168651           I. Rakitić   30
# 63   199556          M. Verratti   25
# 67   189509               Thiago   27
# 78   223848  S. Milinković-Savić   23
# 82   212622           J. Kimmich   23
# 83   208421                 Saúl   23
# 90   189513               Parejo   29
# 99   179846           S. Khedira   31
# 114  212198      Bruno Fernandes   23
# 117  211117              D. Alli   22
# 121  205498             Jorginho   26
# 136  186942          I. Gündoğan   27
# 143  177413            A. Witsel   29
# 161  220971             N. Keïta   23
# 162  219683           C. Tolisso   23
#
#                                               Photo Nationality  \
# 4    https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...

# %%
df6[['Overall','FKAccuracy','LongPassing','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','FKAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head()
# Out:
#     Overall  FKAccuracy  LongPassing  Dribbling  SprintSpeed  Acceleration  \
# 4        91        83.0         91.0       86.0         76.0          78.0
# 6        91        78.0         88.0       90.0         72.0          80.0
# 11       90        84.0         93.0       81.0         62.0          64.0
# 13       90        77.0         87.0       89.0         64.0          70.0
# 53       87        84.0         90.0       84.0         59.0          66.0
#
#     Agility  ShotPower  Strength  LongShots  Stamina  BallControl Position  \
# 4      79.0       91.0      75.0       91.0     90.0         91.0      RCM
# 6      93.0       79.0      58.0       82.0     89.0         93.0      RCM
# 11     70.0       87.0      73.0       92.0     75.0         90.0      LCM
# 13     92.0       72.0      52.0       75.0     78.0         94.0      LCM
# 53     72.0       84.0      66.0       90.0     84.0         87.0      RCM
#
# ...

# %%
df6[['Overall','FKAccuracy','LongPassing','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','FKAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head().plot(kind='line',x='Name',y='Overall')
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
df6['Wage_in_thousands_€']=df6['Wage'].mean()
df6
# Out:
#          ID                 Name  Age  \
# 4    192985         K. De Bruyne   27
# 6    177003            L. Modrić   32
# 11   182521             T. Kroos   28
# 13   168542          David Silva   32
# 52   171877            M. Hamšík   30
# 53   168651           I. Rakitić   30
# 63   199556          M. Verratti   25
# 67   189509               Thiago   27
# 78   223848  S. Milinković-Savić   23
# 82   212622           J. Kimmich   23
# 83   208421                 Saúl   23
# 90   189513               Parejo   29
# 99   179846           S. Khedira   31
# 114  212198      Bruno Fernandes   23
# 117  211117              D. Alli   22
# 121  205498             Jorginho   26
# 136  186942          I. Gündoğan   27
# 143  177413            A. Witsel   29
# 161  220971             N. Keïta   23
# 162  219683           C. Tolisso   23
#
#                                               Photo Nationality  \
# 4    https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...

# %%
df66=df1[(df1['Position']=='RCM') & (df1['Position']=='LCM') & ((df1['Position']=='CM'))].head(20)
df66
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value, Wage, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause 2]
# Index: []
#
# [0 rows x 60 columns]

# %%
df7=df1[(df1['Position']=='LDM') | (df1['Position']=='LM')].head(20)
df7
# Out:
#          ID             Name  Age  \
# 14   215914         N. Kanté   27
# 33   188567    P. Aubameyang   29
# 58   208722          S. Mané   26
# 65   190483    Douglas Costa   27
# 68   188350          M. Reus   29
# 86   193747             Koke   26
# 91   187961         Paulinho   29
# 94   184267       Y. Brahimi   28
# 97   181458       I. Perišić   29
# 103  170890       B. Matuidi   31
# 119  207865       Marquinhos   24
# 125  200104           H. Son   25
# 163  213565         T. Lemar   22
# 164  213345         K. Coman   22
# 173  208418      Y. Carrasco   24
# 185  201995  Felipe Anderson   25
# 217  176266      Lucas Leiva   31
# 221  156616        F. Ribéry   35
# 234  224411   Gonçalo Guedes   21
# 244  212194        J. Brandt   22
#
#                                               Photo     Nationality  \
# 14   https://cdn.sofifa.org/players/4/19/215914.png          France
# 33   https://cdn.sofifa.org/players/4/19/188567.png           Gabon
# ...

# %%
df7[['Overall','Finishing','Marking','Dribbling','Interceptions','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Finishing','Marking','Dribbling','Interceptions','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head()
# Out:
#     Overall  Finishing  Marking  Dribbling  Interceptions  Acceleration  \
# 14       89       65.0     90.0       79.0           92.0          82.0
# 33       88       88.0     27.0       79.0           48.0          93.0
# 68       86       87.0     47.0       87.0           50.0          86.0
# 58       86       84.0     42.0       87.0           35.0          95.0
# 65       86       67.0     45.0       92.0           48.0          97.0
#
#     Agility  ShotPower  Strength  LongShots  Stamina  BallControl Position  \
# 14     82.0       71.0      76.0       69.0     96.0         80.0      LDM
# 33     76.0       82.0      76.0       79.0     76.0         82.0       LM
# 68     86.0       88.0      67.0       86.0     73.0         86.0       LM
# 58     91.0       82.0      67.0       74.0     84.0         86.0       LM
# 65     93.0       86.0      63.0       80.0     78.0         91.0       LM
#
#              Name  Value   Wage     Work Rate Contract Valid Until
# ...

# %%
df7[['Overall','Finishing','Marking','Dribbling','Interceptions','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Finishing','Marking','Dribbling','Interceptions','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head().plot(kind='line',x='Name',y='Overall')
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
df7['Wage_in_thousands_€']=df7['Wage'].mean()
df7
# Out:
#          ID             Name  Age  \
# 14   215914         N. Kanté   27
# 33   188567    P. Aubameyang   29
# 58   208722          S. Mané   26
# 65   190483    Douglas Costa   27
# 68   188350          M. Reus   29
# 86   193747             Koke   26
# 91   187961         Paulinho   29
# 94   184267       Y. Brahimi   28
# 97   181458       I. Perišić   29
# 103  170890       B. Matuidi   31
# 119  207865       Marquinhos   24
# 125  200104           H. Son   25
# 163  213565         T. Lemar   22
# 164  213345         K. Coman   22
# 173  208418      Y. Carrasco   24
# 185  201995  Felipe Anderson   25
# 217  176266      Lucas Leiva   31
# 221  156616        F. Ribéry   35
# 234  224411   Gonçalo Guedes   21
# 244  212194        J. Brandt   22
#
#                                               Photo     Nationality  \
# 14   https://cdn.sofifa.org/players/4/19/215914.png          France
# 33   https://cdn.sofifa.org/players/4/19/188567.png           Gabon
# ...

# %%
df77=df1[(df1['Position']=='LDM') & (df1['Position']=='LM')].head(20)
df77
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value, Wage, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause 2]
# Index: []
#
# [0 rows x 60 columns]

# %%
df9=df1[(df1['Position']=='RDM') | (df1['Position']=='RM')].head(20)
df9
# Out:
#          ID             Name  Age  \
# 25   231747        K. Mbappé   19
# 26   209331         M. Salah   26
# 45   195864         P. Pogba   25
# 122  204970       F. Thauvin   25
# 134  190584     Illarramendi   28
# 137  185020    José Callejón   31
# 138  183898      A. Di María   30
# 153   20775         Quaresma   34
# 154    9014        A. Robben   34
# 170  208808        Q. Promes   26
# 186  200949      Lucas Moura   25
# 198  193474         I. Gueye   28
# 199  192883    H. Mkhitaryan   29
# 211  178088        Juan Mata   30
# 223   53302      D. De Rossi   34
# 233  227055   Gelson Martins   23
# 243  212404  F. Bernardeschi   24
# 246  210617  Samu Castillejo   23
# 256  205678         E. Višća   28
# 260  202371       T. Meunier   26
#
#                                               Photo         Nationality  \
# 25   https://cdn.sofifa.org/players/4/19/231747.png              France
# 26   https://cdn.sofifa.org/players/4/19/209331.png               Egypt
# ...

# %%
df9[['Overall','Finishing','Marking','Dribbling','Interceptions','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Finishing','Marking','Dribbling','Interceptions','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head()
# Out:
#      Overall  Finishing  Marking  Dribbling  Interceptions  Acceleration  \
# 26        88       90.0     38.0       89.0           55.0          94.0
# 25        88       88.0     34.0       90.0           38.0          96.0
# 45        87       73.0     66.0       87.0           66.0          71.0
# 154       84       85.0     30.0       89.0           37.0          83.0
# 122       84       81.0     46.0       85.0           42.0          87.0
#
#      Agility  ShotPower  Strength  LongShots  Stamina  BallControl Position  \
# 26      91.0       77.0      70.0       83.0     84.0         88.0       RM
# 25      92.0       79.0      71.0       78.0     83.0         91.0       RM
# 45      74.0       90.0      89.0       81.0     88.0         90.0      RDM
# 154     87.0       86.0      67.0       86.0     64.0         88.0       RM
# 122     86.0       83.0      66.0       82.0     83.0         86.0       RM
#
#            Name  Value   Wage     Work Rate Contract Valid Until
# ...

# %%
df9[['Overall','Finishing','Marking','Dribbling','Interceptions','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Finishing','Marking','Dribbling','Interceptions','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head().plot(kind='line',x='Name',y='Overall')
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
df9['Wage_in_thousands_€']=df9['Wage'].mean()
df9
# Out:
#          ID             Name  Age  \
# 25   231747        K. Mbappé   19
# 26   209331         M. Salah   26
# 45   195864         P. Pogba   25
# 122  204970       F. Thauvin   25
# 134  190584     Illarramendi   28
# 137  185020    José Callejón   31
# 138  183898      A. Di María   30
# 153   20775         Quaresma   34
# 154    9014        A. Robben   34
# 170  208808        Q. Promes   26
# 186  200949      Lucas Moura   25
# 198  193474         I. Gueye   28
# 199  192883    H. Mkhitaryan   29
# 211  178088        Juan Mata   30
# 223   53302      D. De Rossi   34
# 233  227055   Gelson Martins   23
# 243  212404  F. Bernardeschi   24
# 246  210617  Samu Castillejo   23
# 256  205678         E. Višća   28
# 260  202371       T. Meunier   26
#
#                                               Photo         Nationality  \
# 25   https://cdn.sofifa.org/players/4/19/231747.png              France
# 26   https://cdn.sofifa.org/players/4/19/209331.png               Egypt
# ...

# %%
df99=df1[(df1['Position']=='RDM') & (df1['Position']=='RM')].head(20)
df99
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value, Wage, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause 2]
# Index: []
#
# [0 rows x 60 columns]

# %%
df10=df1[(df1['Position']=='CAM') | (df1['Position']=='LAM')| (df1['Position']=='RAM') ].head(20)
df10
# Out:
#          ID              Name  Age  \
# 17   194765      A. Griezmann   27
# 28   198710      J. Rodríguez   26
# 31   190460        C. Eriksen   26
# 61   201942   Roberto Firmino   26
# 66   189596         T. Müller   28
# 74   176635           M. Özil   29
# 80   216594          N. Fekir   24
# 96   181872          A. Vidal   31
# 101  178518     R. Nainggolan   30
# 129  193082       J. Cuadrado   30
# 144  177388          D. Payet   31
# 166  212523  Anderson Talisca   24
# 171  208670         H. Ziyech   25
# 208  184942          Giuliano   28
# 254  207494        J. Lingard   25
# 263  201400           Rafinha   25
# 282  191180        J. Pastore   29
# 289  186561         A. Ramsey   27
# 292  184484     G. Sigurðsson   28
# 295  184144         N. Gaitán   30
#
#                                               Photo Nationality  \
# 17   https://cdn.sofifa.org/players/4/19/194765.png      France
# 28   https://cdn.sofifa.org/players/4/19/198710.png    Colombia
# ...

# %%
df10[['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head()
# Out:
#     Overall  Finishing  HeadingAccuracy  Dribbling  SprintSpeed  Acceleration  \
# 17       89       90.0             84.0       88.0         85.0          88.0
# 28       88       83.0             62.0       85.0         67.0          73.0
# 31       88       80.0             52.0       84.0         73.0          75.0
# 66       86       87.0             82.0       75.0         75.0          73.0
# 61       86       87.0             77.0       87.0         77.0          78.0
#
#     Agility  ShotPower  Strength  LongShots  Stamina  BallControl Position  \
# 17     90.0       80.0      62.0       82.0     83.0         90.0      CAM
# 28     83.0       86.0      68.0       92.0     70.0         90.0      LAM
# 31     79.0       84.0      58.0       89.0     92.0         91.0      CAM
# 66     75.0       78.0      68.0       80.0     87.0         82.0      CAM
# 61     80.0       81.0      74.0       76.0     90.0         88.0      CAM
#
# ...

# %%
df10[['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head().plot(kind='line',x='Name',y='Overall')
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
df10['Wage_in_thousands_€']=df10['Wage'].mean()
df10
# Out:
#          ID              Name  Age  \
# 17   194765      A. Griezmann   27
# 28   198710      J. Rodríguez   26
# 31   190460        C. Eriksen   26
# 61   201942   Roberto Firmino   26
# 66   189596         T. Müller   28
# 74   176635           M. Özil   29
# 80   216594          N. Fekir   24
# 96   181872          A. Vidal   31
# 101  178518     R. Nainggolan   30
# 129  193082       J. Cuadrado   30
# 144  177388          D. Payet   31
# 166  212523  Anderson Talisca   24
# 171  208670         H. Ziyech   25
# 208  184942          Giuliano   28
# 254  207494        J. Lingard   25
# 263  201400           Rafinha   25
# 282  191180        J. Pastore   29
# 289  186561         A. Ramsey   27
# 292  184484     G. Sigurðsson   28
# 295  184144         N. Gaitán   30
#
#                                               Photo Nationality  \
# 17   https://cdn.sofifa.org/players/4/19/194765.png      France
# 28   https://cdn.sofifa.org/players/4/19/198710.png    Colombia
# ...

# %%
df100=df1[(df1['Position']=='CAM') & (df1['Position']=='LAM')& (df1['Position']=='RAM') ].head(20)
df100
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value, Wage, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause 2]
# Index: []
#
# [0 rows x 60 columns]

# %%
df11=df1[(df1['Position']=='CDM') | (df1['Position']=='CM') ].head(20)
df11
# Out:
#          ID                 Name  Age  \
# 20   189511      Sergio Busquets   29
# 27   200145             Casemiro   26
# 67   189509               Thiago   27
# 72   180206            M. Pjanić   28
# 75   135507          Fernandinho   33
# 78   223848  S. Milinković-Savić   23
# 118  209499              Fabinho   24
# 120  207566     William Carvalho   26
# 121  205498             Jorginho   26
# 132  191202             N. Matić   29
# 136  186942          I. Gündoğan   27
# 142  178562            E. Banega   30
# 161  220971             N. Keïta   23
# 162  219683           C. Tolisso   23
# 168  210008            A. Rabiot   23
# 169  209658          L. Goretzka   23
# 184  202166           J. Draxler   24
# 187  200888       Danilo Pereira   26
# 203  189712         K. Strootman   28
# 215  177610        Javi Martínez   29
#
#                                               Photo         Nationality  \
# 20   https://cdn.sofifa.org/players/4/19/189511.png               Spain
# ...

# %%
df11[['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head()
# Out:
#     Overall  Finishing  HeadingAccuracy  Dribbling  SprintSpeed  Acceleration  \
# 20       89       67.0             68.0       80.0         52.0          50.0
# 27       88       59.0             76.0       69.0         65.0          59.0
# 75       86       69.0             63.0       77.0         67.0          68.0
# 67       86       69.0             54.0       90.0         69.0          78.0
# 72       86       60.0             60.0       86.0         66.0          66.0
#
#     Agility  ShotPower  Strength  LongShots  Stamina  BallControl Position  \
# 20     66.0       61.0      77.0       54.0     86.0         88.0      CDM
# 27     62.0       86.0      89.0       79.0     87.0         78.0      CDM
# 75     72.0       83.0      76.0       78.0     79.0         82.0      CDM
# 67     90.0       75.0      59.0       79.0     75.0         90.0       CM
# 72     77.0       78.0      66.0       82.0     78.0         89.0      CDM
#
# ...

# %%
df11[['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head().plot(kind='line',x='Name',y='Overall')
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
df11['Wage_in_thousands_€']=df11['Wage'].mean()
df11
# Out:
#          ID                 Name  Age  \
# 20   189511      Sergio Busquets   29
# 27   200145             Casemiro   26
# 67   189509               Thiago   27
# 72   180206            M. Pjanić   28
# 75   135507          Fernandinho   33
# 78   223848  S. Milinković-Savić   23
# 118  209499              Fabinho   24
# 120  207566     William Carvalho   26
# 121  205498             Jorginho   26
# 132  191202             N. Matić   29
# 136  186942          I. Gündoğan   27
# 142  178562            E. Banega   30
# 161  220971             N. Keïta   23
# 162  219683           C. Tolisso   23
# 168  210008            A. Rabiot   23
# 169  209658          L. Goretzka   23
# 184  202166           J. Draxler   24
# 187  200888       Danilo Pereira   26
# 203  189712         K. Strootman   28
# 215  177610        Javi Martínez   29
#
#                                               Photo         Nationality  \
# 20   https://cdn.sofifa.org/players/4/19/189511.png               Spain
# ...

# %%
df111=df1[(df1['Position']=='CDM') & (df1['Position']=='CM') ].head(20)
df111
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value, Wage, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause 2]
# Index: []
#
# [0 rows x 60 columns]

# %%
df16=df1[(df1['Position']=='RCB') | (df1['Position']=='CB') |(df1['Position']=='LCB')].head(20)
df16
# Out:
#          ID             Name  Age  \
# 8    155862     Sergio Ramos   32
# 12   182493         D. Godín   32
# 24   138956     G. Chiellini   33
# 34   178603       M. Hummels   29
# 39   164240     Thiago Silva   33
# 42   205600        S. Umtiti   24
# 44   201024     K. Koulibaly   27
# 51   172871    J. Vertonghen   31
# 54   152729            Piqué   31
# 59   203376      V. van Dijk   26
# 62   201535        R. Varane   25
# 70   184344       L. Bonucci   31
# 71   184087  T. Alderweireld   29
# 73   177509       M. Benatia   31
# 77   232363      M. Škriniar   23
# 88   192774       K. Manolas   27
# 89   192366      N. Otamendi   30
# 95   183907       J. Boateng   29
# 102  171919            Naldo   35
# 104  168609          Miranda   33
#
#                                               Photo  Nationality  \
# 8    https://cdn.sofifa.org/players/4/19/155862.png        Spain
# 12   https://cdn.sofifa.org/players/4/19/182493.png      Uruguay
# ...

# %%
df16[['Overall','Interceptions','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head()
# Out:
#     Overall  Interceptions  Finishing  HeadingAccuracy  Dribbling  \
# 8        91           90.0       60.0             91.0       63.0
# 12       90           88.0       42.0             92.0       53.0
# 24       89           88.0       33.0             83.0       58.0
# 34       88           92.0       55.0             87.0       68.0
# 39       88           89.0       38.0             81.0       62.0
#
#     SprintSpeed  Acceleration  Agility  ShotPower  Strength  LongShots  \
# 8          75.0          76.0     78.0       79.0      83.0       59.0
# 12         68.0          68.0     58.0       67.0      88.0       43.0
# 24         75.0          63.0     54.0       78.0      89.0       49.0
# 34         64.0          53.0     63.0       71.0      84.0       51.0
# 39         72.0          70.0     68.0       71.0      82.0       68.0
#
#     Stamina  BallControl Position          Name  Value   Wage     Work Rate  \
# ...

# %%
df16[['Overall','Interceptions','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Finishing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head().plot(kind='line',x='Name',y='Overall')
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
df16['Wage_in_thousands_€']=df16['Wage'].mean()
df16
# Out:
#          ID             Name  Age  \
# 8    155862     Sergio Ramos   32
# 12   182493         D. Godín   32
# 24   138956     G. Chiellini   33
# 34   178603       M. Hummels   29
# 39   164240     Thiago Silva   33
# 42   205600        S. Umtiti   24
# 44   201024     K. Koulibaly   27
# 51   172871    J. Vertonghen   31
# 54   152729            Piqué   31
# 59   203376      V. van Dijk   26
# 62   201535        R. Varane   25
# 70   184344       L. Bonucci   31
# 71   184087  T. Alderweireld   29
# 73   177509       M. Benatia   31
# 77   232363      M. Škriniar   23
# 88   192774       K. Manolas   27
# 89   192366      N. Otamendi   30
# 95   183907       J. Boateng   29
# 102  171919            Naldo   35
# 104  168609          Miranda   33
#
#                                               Photo  Nationality  \
# 8    https://cdn.sofifa.org/players/4/19/155862.png        Spain
# 12   https://cdn.sofifa.org/players/4/19/182493.png      Uruguay
# ...

# %%
df16=df1[(df1['Position']=='RCB') & (df1['Position']=='CB') &(df1['Position']=='LCB')].head(20)
df16
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value, Wage, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause 2]
# Index: []
#
# [0 rows x 60 columns]

# %%
df17=df1[(df1['Position']=='RB') | (df1['Position']=='RWB')].head(20)
df17
# Out:
#          ID             Name  Age  \
# 69   184432      Azpilicueta   28
# 123  204963         Carvajal   26
# 135  188377        K. Walker   28
# 192  199564    Sergi Roberto   26
# 216  177457        L. Bender   29
# 247  210514     João Cancelo   24
# 258  203551      A. Florenzi   27
# 276  193525  Mário Fernandes   27
# 290  186345      K. Trippier   27
# 314  146530       Dani Alves   35
# 324  227928    Nélson Semedo   24
# 339  210864         E. Hysaj   24
# 341  210243  Ricardo Pereira   24
# 354  203890      S. Vrsaljko   26
# 392  173771      L. Piszczek   33
# 394  172522          D. Wass   29
# 417  234035        Odriozola   22
# 424  226851        B. Pavard   22
# 450  207862        M. Ginter   24
# 464  203747  Héctor Bellerín   23
#
#                                               Photo Nationality  \
# 69   https://cdn.sofifa.org/players/4/19/184432.png       Spain
# 123  https://cdn.sofifa.org/players/4/19/204963.png       Spain
# ...

# %%
df17[['Overall','Interceptions','Crossing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Crossing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head()
# Out:
#      Overall  Interceptions  Crossing  HeadingAccuracy  Dribbling  \
# 69        86           89.0      81.0             76.0       69.0
# 123       84           83.0      83.0             70.0       76.0
# 135       84           81.0      81.0             74.0       79.0
# 192       83           81.0      85.0             72.0       78.0
# 216       83           86.0      69.0             78.0       72.0
#
#      SprintSpeed  Acceleration  Agility  ShotPower  Strength  LongShots  \
# 69          76.0          76.0     72.0       68.0      71.0       60.0
# 123         84.0          79.0     81.0       64.0      74.0       36.0
# 135         93.0          86.0     67.0       86.0      75.0       69.0
# 192         79.0          78.0     69.0       65.0      69.0       66.0
# 216         67.0          66.0     65.0       74.0      76.0       71.0
#
#      Stamina  BallControl Position           Name  Value   Wage  \
# 69      87.0         77.0       RB    Azpilicueta   35.0  175.0
# ...

# %%
df17[['Overall','Interceptions','Crossing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Crossing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head().plot(kind='line',x='Name',y='Overall')
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
df17['Wage_in_thousands_€']=df17['Wage'].mean()
df17
# Out:
#          ID             Name  Age  \
# 69   184432      Azpilicueta   28
# 123  204963         Carvajal   26
# 135  188377        K. Walker   28
# 192  199564    Sergi Roberto   26
# 216  177457        L. Bender   29
# 247  210514     João Cancelo   24
# 258  203551      A. Florenzi   27
# 276  193525  Mário Fernandes   27
# 290  186345      K. Trippier   27
# 314  146530       Dani Alves   35
# 324  227928    Nélson Semedo   24
# 339  210864         E. Hysaj   24
# 341  210243  Ricardo Pereira   24
# 354  203890      S. Vrsaljko   26
# 392  173771      L. Piszczek   33
# 394  172522          D. Wass   29
# 417  234035        Odriozola   22
# 424  226851        B. Pavard   22
# 450  207862        M. Ginter   24
# 464  203747  Héctor Bellerín   23
#
#                                               Photo Nationality  \
# 69   https://cdn.sofifa.org/players/4/19/184432.png       Spain
# 123  https://cdn.sofifa.org/players/4/19/204963.png       Spain
# ...

# %%
df17=df1[(df1['Position']=='RB') & (df1['Position']=='RWB')].head(20)
df17
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value, Wage, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause 2]
# Index: []
#
# [0 rows x 60 columns]

# %%
df18=df1[(df1['Position']=='LB') | (df1['Position']=='LWB')].head(20)
df18
# Out:
#          ID            Name  Age  \
# 35   176676         Marcelo   30
# 49   189332      Jordi Alba   29
# 64   191043     Alex Sandro   27
# 85   197445        D. Alaba   26
# 106  164169     Filipe Luís   32
# 112  212462     Alex Telles   25
# 200  192638   Marcos Alonso   27
# 238  220814    L. Hernández   22
# 241  216267    A. Robertson   24
# 291  185103      A. Kolarov   32
# 342  210035        Grimaldo   22
# 348  205923       B. Davies   25
# 352  204884        B. Mendy   23
# 358  201454      F. Ghoulam   27
# 396  169595         D. Rose   27
# 419  230347  Welington Dano   30
# 428  224334        M. Acuña   26
# 443  211688            Gayà   23
# 445  211256   N. Tagliafico   25
# 454  205988         L. Shaw   22
#
#                                               Photo Nationality  \
# 35   https://cdn.sofifa.org/players/4/19/176676.png      Brazil
# 49   https://cdn.sofifa.org/players/4/19/189332.png       Spain
# ...

# %%
df18[['Overall','Interceptions','Crossing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Crossing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head()
# Out:
#      Overall  Interceptions  Crossing  HeadingAccuracy  Dribbling  \
# 35        88           85.0      90.0             75.0       90.0
# 49        87           84.0      87.0             70.0       80.0
# 64        86           82.0      84.0             76.0       80.0
# 106       85           84.0      86.0             72.0       77.0
# 85        85           84.0      81.0             75.0       79.0
#
#      SprintSpeed  Acceleration  Agility  ShotPower  Strength  LongShots  \
# 35          82.0          83.0     86.0       83.0      78.0       70.0
# 49          93.0          93.0     90.0       64.0      61.0       66.0
# 64          86.0          83.0     79.0       80.0      79.0       72.0
# 106         75.0          76.0     75.0       71.0      74.0       60.0
# 85          86.0          79.0     79.0       83.0      71.0       82.0
#
#      Stamina  BallControl Position         Name  Value   Wage     Work Rate  \
# ...

# %%
df18[['Overall','Interceptions','Crossing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate','Contract Valid Until']].sort_values(by=['Overall','Crossing','HeadingAccuracy','Dribbling','SprintSpeed','Acceleration','Agility','ShotPower','Strength','LongShots','Stamina','BallControl','Position','Name','Value','Wage','Work Rate'],ascending=False).head().plot(kind='line',x='Name',y='Overall')
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
df18['Wage_in_thousands_€']=df18['Wage'].mean()
df18
# Out:
#          ID            Name  Age  \
# 35   176676         Marcelo   30
# 49   189332      Jordi Alba   29
# 64   191043     Alex Sandro   27
# 85   197445        D. Alaba   26
# 106  164169     Filipe Luís   32
# 112  212462     Alex Telles   25
# 200  192638   Marcos Alonso   27
# 238  220814    L. Hernández   22
# 241  216267    A. Robertson   24
# 291  185103      A. Kolarov   32
# 342  210035        Grimaldo   22
# 348  205923       B. Davies   25
# 352  204884        B. Mendy   23
# 358  201454      F. Ghoulam   27
# 396  169595         D. Rose   27
# 419  230347  Welington Dano   30
# 428  224334        M. Acuña   26
# 443  211688            Gayà   23
# 445  211256   N. Tagliafico   25
# 454  205988         L. Shaw   22
#
#                                               Photo Nationality  \
# 35   https://cdn.sofifa.org/players/4/19/176676.png      Brazil
# 49   https://cdn.sofifa.org/players/4/19/189332.png       Spain
# ...

# %%
df188=df1[(df1['Position']=='LB') & (df1['Position']=='LWB')].head(20)
df188
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value, Wage, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause 2]
# Index: []
#
# [0 rows x 60 columns]

# %%
df1['Position'].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB', nan], dtype=object)

# %%
df1.groupby(by='Position')['Wage'].mean()
# Out:
# Position
# CAM    10.229645
# CB      7.704724
# CDM     9.315401
# CF     10.216216
# CM      8.340746
# GK      6.803951
# LAM    26.142857
# LB      8.726929
# LCB    11.498457
# LCM    14.131646
# LDM    11.860082
# LF     44.666667
# LM      9.656621
# LS     15.260870
# LW     13.068241
# LWB     9.076923
# RAM    19.095238
# RB      8.604183
# RCB    12.688822
# RCM    14.404092
# RDM    12.149194
# RF     52.687500
# RM      9.540925
# RS     14.379310
# RW     14.432432
# RWB     8.597701
# ST      9.938197
# Name: Wage, dtype: float64

# %%
df1.groupby(by='Position')['Wage'].max().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Position'>

# %%
df24=df2[['Overall','Name','Wage','Age','Value']].where(df1['Contract Valid Until']=='2020').sort_values(by='Overall',ascending=False).head(20) 
df24
# Out:
#      Overall             Name   Wage   Age  Value
# 3       91.0           De Gea  260.0  27.0   72.0
# 8       91.0     Sergio Ramos  380.0  32.0   51.0
# 5       91.0        E. Hazard  340.0  27.0   93.0
# 6       91.0        L. Modrić  420.0  32.0   67.0
# 13      90.0      David Silva  285.0  32.0   60.0
# 21      89.0        E. Cavani  200.0  31.0   60.0
# 24      89.0     G. Chiellini  215.0  33.0   27.0
# 31      88.0       C. Eriksen  205.0  26.0   73.5
# 39      88.0     Thiago Silva  165.0  33.0   24.0
# 46      87.0         K. Navas  195.0  31.0   30.5
# 49      87.0       Jordi Alba  250.0  29.0   38.0
# 50      87.0       D. Mertens  135.0  31.0   45.0
# 52      87.0        M. Hamšík  125.0  30.0   46.5
# 64      86.0      Alex Sandro  160.0  27.0   36.5
# 71      86.0  T. Alderweireld  150.0  29.0   39.0
# 73      86.0       M. Benatia  160.0  31.0   30.0
# 75      86.0      Fernandinho  185.0  33.0   18.0
# 104     85.0          Miranda   96.0  33.0   15.5
# ...

# %%
df24.rename(columns={'Wage':'Wage_in_thousands'},inplace=True)
df24
# Out:
#      Overall             Name  Wage_in_thousands   Age  Value
# 3       91.0           De Gea              260.0  27.0   72.0
# 8       91.0     Sergio Ramos              380.0  32.0   51.0
# 5       91.0        E. Hazard              340.0  27.0   93.0
# 6       91.0        L. Modrić              420.0  32.0   67.0
# 13      90.0      David Silva              285.0  32.0   60.0
# 21      89.0        E. Cavani              200.0  31.0   60.0
# 24      89.0     G. Chiellini              215.0  33.0   27.0
# 31      88.0       C. Eriksen              205.0  26.0   73.5
# 39      88.0     Thiago Silva              165.0  33.0   24.0
# 46      87.0         K. Navas              195.0  31.0   30.5
# 49      87.0       Jordi Alba              250.0  29.0   38.0
# 50      87.0       D. Mertens              135.0  31.0   45.0
# 52      87.0        M. Hamšík              125.0  30.0   46.5
# 64      86.0      Alex Sandro              160.0  27.0   36.5
# ...

# %%
df24=df2[['Overall','Name','Wage','Age','Value']].where(df1['Contract Valid Until']=='2020').sort_values(by='Overall',ascending=False).head(20).plot(kind='bar',x='Name',y='Overall')

# %%
df24['Wage_in_thousands'].mean()
# Out:
# 205.45

# %%
df24['Age'].mean()
# Out:
# 30.65

# %%
df24[['Value','Overall']].corr()
#AS WE CAN SEE THERE IS A 78.6% CORRELATION AMOUNNG VALUE AND OVR RATING
# Out:
#             Value   Overall
# Value    1.000000  0.786717
# Overall  0.786717  1.000000

# %%
sns.heatmap(df24[['Value','Overall']].corr(),annot=True)
# Out:
# <AxesSubplot:>
